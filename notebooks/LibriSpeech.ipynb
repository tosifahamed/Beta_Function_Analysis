# %% [markdown]
# # Installing Whisper
#
# The commands below will install the Python packages needed to use Whisper models and evaluate the transcription results.

# %%
! pip install git+https://github.com/openai/whisper.git
! pip install jiwer
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-xyzic57s
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-xyzic57s
#   Resolved https://github.com/openai/whisper.git to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 129.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Loading the LibriSpeech dataset
#
# The following will load the test-clean split of the LibriSpeech corpus using torchaudio.

# %%
import os
import numpy as np

try:
    import tensorflow  # required in Colab to avoid protobuf compatibility issues
except ImportError:
    pass

import torch
import pandas as pd
import whisper
import torchaudio

from tqdm.notebook import tqdm


DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
class LibriSpeech(torch.utils.data.Dataset):
    """
    A simple class to wrap LibriSpeech and trim/pad the audio to 30 seconds.
    It will drop the last few seconds of a very small portion of the utterances.
    """
    def __init__(self, split="test-clean", device=DEVICE):
        self.dataset = torchaudio.datasets.LIBRISPEECH(
            root=os.path.expanduser("~/.cache"),
            url=split,
            download=True,
        )
        self.device = device

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, item):
        audio, sample_rate, text, _, _, _ = self.dataset[item]
        assert sample_rate == 16000
        audio = whisper.pad_or_trim(audio.flatten()).to(self.device)
        mel = whisper.log_mel_spectrogram(audio)

        return (mel, text)

# %%
# prompt: convert the SaketAnoj.m4a file to mp3

# !ffmpeg -i SaketAnoj.m4a -acodec libmp3lame SaketAnoj.mp3

# %%
# prompt: I want to transcribe the entire audio file SaketAnoj.mp3 into text

model = whisper.load_model("base")
result = model.transcribe("SaketAnoj.mp3")
print(result["text"])
# Out:
#  method as opposed to the other way around. I don't know how you feel I know which foot up. Yeah, I think that that was also my sort of like I guess at that eyes level. I think what was missing in terms of work, then a kind of shift in emphasis that would maybe be good is to yeah really just make it clear that these will be very useful for something without just saying it's like a new method and I think there's also ties in with like superficially it seems like you know their methods do all of these kinds of things all right right so I think you know you have to just make it clear that this isn't just like a fun like math problem that you want to solve but you know there's already methods for like clustering and neural data you know gene regulatory now or like all of this is like you pretty established faith. So I think yeah this is where if you can lay out like a very sort of specific problem and then really use that to be like you know this this is something that we really can't do
# ...
